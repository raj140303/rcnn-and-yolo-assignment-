# %%
# theory qquestion

# %%
# TensorFlow 2.0
# 1. What is TensorFlow 2.0, and how is it different from TensorFlow 1.x?



# TensorFlow 2.0 is a major upgrade to TensorFlow that focuses on simplicity and ease of use. Key differences:

# Uses eager execution by default (imperative style).

# Integrates Keras as the high-level API.

# Removes redundant APIs for cleaner code.

# Improved compatibility with Pythonic code.




# 2. How do you install TensorFlow 2.0?

# Use pip:

# bash
# Copy
# Edit
# pip install tensorflow



# 3. What is the primary function of tf.function in TensorFlow 2.0?

# It converts a Python function into a TensorFlow graph for performance optimization (i.e., faster execution and better deployment).



# 4. What is the purpose of the Model class in TensorFlow 2.0?

# It provides the base class for creating models in Keras-style. You can:

# Define your own custom model logic.

# Use built-in methods like compile(), fit(), evaluate(), and predict().




# 5. How do you create a neural network using TensorFlow 2.0?

# Example using Keras:

# python
# Copy
# Edit
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense

# model = Sequential([
#     Dense(128, activation='relu', input_shape=(784,)),
#     Dense(10, activation='softmax')
# ])



# 6. What is the importance of Tensor space in TensorFlow?

# Tensors are the fundamental data structure used for all computations (similar to NumPy arrays but with GPU acceleration and gradient tracking).



# 7. How can TensorBoard be integrated with TensorFlow 2.0?


# TensorBoard helps visualize training:

# python
# Copy
# Edit
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")
# model.fit(x, y, epochs=5, callbacks=[tensorboard_callback])



# 8. What is the purpose of TensorFlow Playground?

# An interactive web-based tool to visualize and experiment with simple neural networks. Great for beginners.



# 9. What is Netron, and how is it useful for deep learning models?


# Netron is a model visualization tool that lets you see the structure of deep learning models in formats like .h5, .pb, .onnx, etc.

# PyTorch



# 10. What is the difference between TensorFlow and PyTorch?

# Feature	TensorFlow	PyTorch
# Execution	Graph (TF1), Eager (TF2)	Eager
# Syntax	Verbose	Pythonic
# Community	Broad	Growing fast
# Debugging	Harder (TF1)	Easier



# 11. How do you install PyTorch?

# Use the official command based on OS and CUDA version. For CPU:

# bash
# Copy
# Edit
# pip install torch torchvision torchaudio


# 12. What is the basic structure of a PyTorch neural network?

# python
# Copy
# Edit
# import torch.nn as nn

# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.fc = nn.Linear(784, 10)

#     def forward(self, x):
#         return self.fc(x)




# 13. What is the significance of tensors in PyTorch?

# Tensors are the core data structure used for computations. They support automatic differentiation and GPU acceleration.



# 14. What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch?

# torch.Tensor: resides in CPU memory.

# torch.cuda.Tensor: resides in GPU memory for faster computation.





# 15. What is the purpose of the torch.optim module in PyTorch?

# It provides optimizers like SGD, Adam, etc., for updating model parameters during training.





# 16. What are some common activation functions used in neural networks?

# ReLU

# Sigmoid

# Tanh

# Softmax

# LeakyReLU




# 17. What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch?

# nn.Module: Allows full flexibility to define any architecture.

# nn.Sequential: Quick way to stack layers linearly.




# 18. How can you monitor training progress in TensorFlow 2.0?

# Use callbacks like:

# TensorBoard

# EarlyStopping

# ModelCheckpoint





# 19. How does the Keras API fit into TensorFlow 2.0?


# Keras is the default high-level API in TensorFlow 2.0, making model building and training more user-friendly.




# 20. What is an example of a deep learning project that can be implemented using TensorFlow 2.0?
# Example: Image classifier using CNNs for MNIST digits.





# 21. What is the main advantage of using pre-trained models in TensorFlow and PyTorch?

# Save time and computational resources.

# Useful for transfer learning (fine-tuning on new tasks with less data).

# %% [markdown]
# PRACTICAL

# %%
# 1. How do you install and verify that TensorFlow 2.0 was installed successfully?






# bash
# Copy
# Edit
# pip install tensorflow
# Verify Installation:

# python
# Copy
# Edit
# import tensorflow as tf
# print(tf.__version__)
#  Output should start with 2. (e.g., 2.15.0).






# 2. How can you define a simple function in TensorFlow 2.0 to perform addition?

# python
# Copy
# Edit
# import tensorflow as tf

# @tf.function
# def add_numbers(a, b):
#     return a + b

# print(add_numbers(tf.constant(3), tf.constant(5)))






# 3. How can you create a simple neural network in TensorFlow 2.0 with one hidden layer?

# python
# Copy
# Edit
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense

# model = Sequential([
#     Dense(64, activation='relu', input_shape=(10,)),  # Hidden layer
#     Dense(1)  # Output layer
# ])
# model.summary()







# 4. How can you visualize the training progress using TensorFlow and Matplotlib?

# python
# Copy
# Edit
# import matplotlib.pyplot as plt

# # After training
# history = model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))

# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.title('Training Progress')
# plt.show()
#  PyTorch





# 5. How do you install PyTorch and verify the PyTorch installation?

# Go to: https://pytorch.org/get-started/locally and select your OS and environment.

# Example install (CPU):

# bash
# Copy
# Edit
# pip install torch torchvision torchaudio
# Verify:

# python
# Copy
# Edit
# import torch
# print(torch.__version__)
# print(torch.cuda.is_available())  # False if using CPU, True if using GPU






# 6. How do you create a simple neural network in PyTorch?

# python
# Copy
# Edit
# import torch.nn as nn
# import torch.nn.functional as F

# class SimpleNN(nn.Module):
#     def __init__(self):
#         super(SimpleNN, self).__init__()
#         self.hidden = nn.Linear(10, 64)
#         self.output = nn.Linear(64, 1)

#     def forward(self, x):
#         x = F.relu(self.hidden(x))
#         return self.output(x)
    





# 7. How do you define a loss function and optimizer in PyTorch?

# python
# Copy
# Edit
# import torch.optim as optim

# model = SimpleNN()
# criterion = nn.MSELoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)






# 8. How do you implement a custom loss function in PyTorch?

# python
# Copy
# Edit
# def custom_loss(output, target):
#     return torch.mean((output - target)**2 + 0.1 * torch.abs(output - target))
# You can use it during training like:

# python
# Copy
# Edit
# loss = custom_loss(predicted, actual)





# 9. How do you save and load a TensorFlow model?

#  Save the entire model:

# python
# Copy
# Edit
# model.save('my_model.h5')  # or use .keras extension
# Load the model:

# python
# Copy
# Edit
# from tensorflow.keras.models import load_model
# model = load_model('my_model.h5')
